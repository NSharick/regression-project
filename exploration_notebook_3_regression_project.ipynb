# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import RFE
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.feature_selection import f_regression, SelectKBest, RFE
import os
from sklearn.impute import SimpleImputer
from env import get_db_url
import warnings
warnings.filterwarnings('ignore')
import math 
#from acquire import acquire_zillow

# %%
def acquire_zillow():
    '''
    This function checks for a copy of the dataset in the local directory 
    and pulls a new copy and saves it if there is not one,
    it then cleans the data by removing significant outliers then
    removing the rows with null values for 'yearbuilt'
    '''
    #assign the file name
    filename = 'zillow3.csv'
    #check if the file exists in the current directory and read it if it is
    if os.path.exists(filename):
        print('Reading from csv file...')
        #read the local .csv into the notebook
        df = pd.read_csv(filename)
        return df
    #assign the sql query to a variable for use in pulling a new copy of the dataset from the database
    query = '''
    SELECT pro.bedroomcnt, pro.bathroomcnt, pro.calculatedfinishedsquarefeet, 
    pro.taxvaluedollarcnt, pro.yearbuilt, pro.fips, pro.lotsizesquarefeet
    FROM properties_2017 AS pro
    JOIN predictions_2017 AS pre USING(parcelid)
    WHERE pro.propertylandusetypeid = 261;
    '''
    #if needed pull a fresh copy of the dataset from the database
    print('Getting a fresh copy from SQL database...')
    df = pd.read_sql(query, get_db_url('zillow'))
    #save a copy of the dataset to the local directory as a .csv file
    df.to_csv(filename, index=False)
    return df

# %%
df = acquire_zillow()
df.head()
# Out:
# Reading from csv file...
#    bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  taxvaluedollarcnt  \
# 0         4.0          3.5                        3100.0          1023282.0
# 1         2.0          1.0                        1465.0           464000.0
# 2         3.0          2.0                        1243.0           564778.0
# 3         4.0          3.0                        2376.0           145143.0
# 4         4.0          3.0                        2962.0           773303.0
#
#    yearbuilt    fips  lotsizesquarefeet
# 0     1998.0  6059.0             4506.0
# 1     1967.0  6111.0            12647.0
# 2     1962.0  6059.0             8432.0
# 3     1970.0  6037.0            13038.0
# 4     1950.0  6037.0            63000.0

# %%
df.shape
# Out:
# (52442, 7)

# %%
df.isnull().sum()
# Out:
# bedroomcnt                        0
# bathroomcnt                       0
# calculatedfinishedsquarefeet     82
# taxvaluedollarcnt                 1
# yearbuilt                       116
# fips                              0
# lotsizesquarefeet               369
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# bedroomcnt                      0
# bathroomcnt                     0
# calculatedfinishedsquarefeet    0
# taxvaluedollarcnt               0
# yearbuilt                       0
# fips                            0
# lotsizesquarefeet               0
# dtype: int64

# %%
df.shape
# Out:
# (51960, 7)

# %%
df.fips.value_counts()
# Out:
# 6037.0    33568
# 6059.0    14034
# 6111.0     4358
# Name: fips, dtype: int64

# %%
df1 = df[df['fips']==6037.0]

# %%
df1.head()
# Out:
#    bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  taxvaluedollarcnt  \
# 3         4.0          3.0                        2376.0           145143.0
# 4         4.0          3.0                        2962.0           773303.0
# 5         2.0          1.0                         738.0           218552.0
# 6         4.0          3.0                        3039.0           220583.0
# 7         4.0          3.0                        2540.0           430108.0
#
#    yearbuilt    fips  lotsizesquarefeet
# 3     1970.0  6037.0            13038.0
# 4     1950.0  6037.0            63000.0
# 5     1922.0  6037.0             4214.0
# 6     1970.0  6037.0            20028.0
# 7     1999.0  6037.0            10384.0

# %%
df1.fips.value_counts()
# Out:
# 6037.0    33568
# Name: fips, dtype: int64

# %%
df2 = df[df['fips']==6059.0]

# %%
df2.fips.value_counts()
# Out:
# 6059.0    14034
# Name: fips, dtype: int64

# %%
df3 = df[df['fips']==6111.0]

# %%
df3.fips.value_counts()
# Out:
# 6111.0    4358
# Name: fips, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# Data Frame 1 split, remove outliers, scale

# %%
train_val, test = train_test_split(df1, train_size = 0.8, random_state=123)
train, validate = train_test_split(train_val, train_size = 0.7, random_state=123)
train.shape, validate.shape, test.shape
# Out:
# ((18797, 7), (8057, 7), (6714, 7))

# %%
def remove_outliers(df, k, col_list):
    ''' this function will remove outliers from a list of columns in a dataframe 
        and return that dataframe. A list of columns with significant outliers is 
        assigned to a variable in the below wrangle function and can be modified if needed
    '''
    #loop throught the columns in the list
    for col in col_list:
        q1, q3 = df[col].quantile([.25, .75])  # get quartiles
        iqr = q3 - q1   # calculate interquartile range
        upper_bound = q3 + k * iqr   # get upper bound
        lower_bound = q1 - k * iqr   # get lower bound
        # return dataframe without outliers
        df = df[(df[col] > lower_bound) & (df[col] < upper_bound)] 
    return df

# %%
out_columns = ['bedroomcnt', 'bathroomcnt','calculatedfinishedsquarefeet', 'lotsizesquarefeet']
train = remove_outliers(train, 1.5, out_columns)

# %%
train.shape
# Out:
# (15388, 7)

# %%
train.describe()
# Out:
#          bedroomcnt   bathroomcnt  calculatedfinishedsquarefeet  \
# count  15388.000000  15388.000000                  15388.000000
# mean       3.084091      1.963088                   1565.216012
# std        0.768743      0.746954                    543.386291
# min        2.000000      1.000000                    152.000000
# 25%        3.000000      1.000000                   1162.750000
# 50%        3.000000      2.000000                   1458.000000
# 75%        4.000000      2.000000                   1860.000000
# max        5.000000      4.000000                   3298.000000
#
#        taxvaluedollarcnt     yearbuilt     fips  lotsizesquarefeet
# count       1.538800e+04  15388.000000  15388.0       15388.000000
# mean        3.770711e+05   1954.808877   6037.0        6760.021445
# std         3.700371e+05     21.523635      0.0        1904.171588
# min         3.254000e+03   1882.000000   6037.0        1548.000000
# 25%         1.497370e+05   1944.000000   6037.0        5501.000000
# 50%         2.932515e+05   1953.000000   6037.0        6538.500000
# 75%         4.756122e+05   1963.000000   6037.0        7694.000000
# max         9.837579e+06   2016.000000   6037.0       12507.000000

# %%
train.fips.value_counts()
# Out:
# 6037.0    15388
# Name: fips, dtype: int64

# %%
x_train = train[['bedroomcnt', 'bathroomcnt', 'calculatedfinishedsquarefeet', 'yearbuilt', 'lotsizesquarefeet']]
y_train = train[['taxvaluedollarcnt']]
x_train.head()
# Out:
#        bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  yearbuilt  \
# 17792         4.0          2.0                        1864.0     1956.0
# 45565         3.0          1.0                        1168.0     1954.0
# 51094         2.0          1.0                         880.0     1924.0
# 44347         4.0          2.0                        1536.0     1913.0
# 32759         3.0          2.0                        1520.0     1954.0
#
#        lotsizesquarefeet
# 17792            10271.0
# 45565             7238.0
# 51094             3097.0
# 44347             4878.0
# 32759             6841.0

# %%
#create a min-max scaler object
scaler = MinMaxScaler()
#fit the scaler with the train data
scaler.fit(x_train)
#output the results of the scaler into a new df to use with feature selection
x_train_scaled = scaler.transform(x_train)
x_train_scaled_df = pd.DataFrame(x_train_scaled, columns=x_train.columns, index=x_train.index)
x_train_scaled_df.head()
# Out:
#        bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  yearbuilt  \
# 17792    0.666667     0.333333                      0.544183   0.552239
# 45565    0.333333     0.000000                      0.322950   0.537313
# 51094    0.000000     0.000000                      0.231405   0.313433
# 44347    0.666667     0.333333                      0.439924   0.231343
# 32759    0.333333     0.333333                      0.434838   0.537313
#
#        lotsizesquarefeet
# 17792           0.795967
# 45565           0.519208
# 51094           0.141345
# 44347           0.303860
# 32759           0.482982

# %%
x_validate = validate[['bedroomcnt', 'bathroomcnt', 'calculatedfinishedsquarefeet', 'yearbuilt','lotsizesquarefeet']]
y_validate = validate[['taxvaluedollarcnt']]
x_validate.head()
# Out:
#        bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  yearbuilt  \
# 21619         3.0          1.0                        1006.0     1955.0
# 9827          2.0          2.0                         988.0     1948.0
# 17521         3.0          2.0                        1444.0     1955.0
# 26823         3.0          1.0                        1478.0     1911.0
# 21839         4.0          5.0                        4135.0     1993.0
#
#        lotsizesquarefeet
# 21619             5929.0
# 9827              2639.0
# 17521             6004.0
# 26823             5096.0
# 21839             5059.0

# %%
x_validate_scaled = scaler.transform(x_validate)
x_validate_scaled_df = pd.DataFrame(x_validate_scaled, columns=x_train.columns, index=x_validate.index)
x_validate_scaled_df.head()
# Out:
#        bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  yearbuilt  \
# 21619    0.333333     0.000000                      0.271456   0.544776
# 9827     0.000000     0.333333                      0.265734   0.492537
# 17521    0.333333     0.333333                      0.410680   0.544776
# 26823    0.333333     0.000000                      0.421488   0.216418
# 21839    0.666667     1.333333                      1.266052   0.828358
#
#        lotsizesquarefeet
# 21619           0.399763
# 9827            0.099553
# 17521           0.406606
# 26823           0.323752
# 21839           0.320376

# %%
predictions = pd.DataFrame({'actual': validate.taxvaluedollarcnt})
predictions.head()
# Out:
#           actual
# 21619   324551.0
# 9827    271013.0
# 17521   117015.0
# 26823   247786.0
# 21839  2690733.0

# %% [markdown]
# ---

# %%
x = x_train_scaled_df
y = y_train
model = LinearRegression()
rfe = RFE(model, n_features_to_select=2).fit(x, y)
print('Top 2 features according to RFE:')
x.columns[rfe.get_support()]
# Out:
# Top 2 features according to RFE:
# Index(['calculatedfinishedsquarefeet', 'yearbuilt'], dtype='object')

# %%
pd.DataFrame({'rfe_ranking': rfe.ranking_}, index=x.columns)
# Out:
#                               rfe_ranking
# bedroomcnt                              3
# bathroomcnt                             2
# calculatedfinishedsquarefeet            1
# yearbuilt                               1
# lotsizesquarefeet                       4

# %% [markdown]
# ---

# %%
x = x_train_scaled_df[['calculatedfinishedsquarefeet']]
z = x_validate_scaled_df[['calculatedfinishedsquarefeet']]
lm = LinearRegression()
lm.fit(x, y_train)
predictions['simple_lm'] = lm.predict(z)
predictions.head()
# Out:
#           actual      simple_lm
# 21619   324551.0  242309.058958
# 9827    271013.0  237971.349836
# 17521   117015.0  347859.980931
# 26823   247786.0  356053.431495
# 21839  2690733.0  996347.494698

# %%
x = x_train_scaled_df[['calculatedfinishedsquarefeet', 'yearbuilt']]
z = x_validate_scaled_df[['calculatedfinishedsquarefeet', 'yearbuilt']]
lm2 = LinearRegression()
lm.fit(x, y_train)
predictions['lm_top2x'] = lm.predict(z)
predictions.head()
# Out:
#           actual      simple_lm      lm_top2x
# 21619   324551.0  242309.058958  2.084590e+05
# 9827    271013.0  237971.349836  2.281397e+05
# 17521   117015.0  347859.980931  3.399862e+05
# 26823   247786.0  356053.431495  5.078790e+05
# 21839  2690733.0  996347.494698  1.011887e+06

# %%
x = x_train_scaled_df[['calculatedfinishedsquarefeet', 'bedroomcnt']]
z = x_validate_scaled_df[['calculatedfinishedsquarefeet', 'bedroomcnt']]
lm2 = LinearRegression()
lm.fit(x, y_train)
predictions['lm1'] = lm.predict(z)
predictions.head()
# Out:
#           actual      simple_lm      lm_top2x      lm_top3x      lm_top4x  \
# 21619   324551.0  242309.058958  2.084590e+05  1.782790e+05  1.443990e+05
# 9827    271013.0  237971.349836  2.281397e+05  2.706052e+05  3.281130e+05
# 17521   117015.0  347859.980931  3.399862e+05  3.500576e+05  3.524372e+05
# 26823   247786.0  356053.431495  5.078790e+05  4.703246e+05  4.416271e+05
# 21839  2690733.0  996347.494698  1.011887e+06  1.036285e+06  1.137089e+06
#
#             lm_allx  polynomial degree 2  polynomial_interaction_only  \
# 21619  1.473943e+05         2.322444e+05                 2.416460e+05
# 9827   3.689665e+05         4.275721e+05                 3.657399e+05
# 17521  3.597829e+05         3.390904e+05                 3.537123e+05
# 26823  4.601591e+05         3.498361e+05                 3.549836e+05
# 21839  1.199510e+06         1.996239e+06                 1.892350e+06
#
#             baseline           lm1
# 21619  377071.081102  2.103221e+05
# 9827   377071.081102  2.859655e+05
# 17521  377071.081102  3.462766e+05
# 26823  377071.081102  3.568302e+05
# 21839  377071.081102  1.100328e+06

# %%
x = x_train_scaled_df[['calculatedfinishedsquarefeet', 'bathroomcnt']]
z = x_validate_scaled_df[['calculatedfinishedsquarefeet', 'bathroomcnt']]
lm2 = LinearRegression()
lm.fit(x, y_train)
predictions['lm2'] = lm.predict(z)
predictions.head()
# Out:
#           actual      simple_lm      lm_top2x      lm_top3x      lm_top4x  \
# 21619   324551.0  242309.058958  2.084590e+05  1.782790e+05  1.443990e+05
# 9827    271013.0  237971.349836  2.281397e+05  2.706052e+05  3.281130e+05
# 17521   117015.0  347859.980931  3.399862e+05  3.500576e+05  3.524372e+05
# 26823   247786.0  356053.431495  5.078790e+05  4.703246e+05  4.416271e+05
# 21839  2690733.0  996347.494698  1.011887e+06  1.036285e+06  1.137089e+06
#
#             lm_allx  polynomial degree 2  polynomial_interaction_only  \
# 21619  1.473943e+05         2.322444e+05                 2.416460e+05
# 9827   3.689665e+05         4.275721e+05                 3.657399e+05
# 17521  3.597829e+05         3.390904e+05                 3.537123e+05
# 26823  4.601591e+05         3.498361e+05                 3.549836e+05
# 21839  1.199510e+06         1.996239e+06                 1.892350e+06
#
#             baseline           lm1           lm2
# 21619  377071.081102  2.103221e+05  2.360834e+05
# 9827   377071.081102  2.859655e+05  2.487405e+05
# 17521  377071.081102  3.462766e+05  3.506079e+05
# 26823  377071.081102  3.568302e+05  3.415250e+05
# 21839  377071.081102  1.100328e+06  1.001794e+06

# %%
x = x_train_scaled_df[['calculatedfinishedsquarefeet', 'lotsizesquarefeet']]
z = x_validate_scaled_df[['calculatedfinishedsquarefeet', 'lotsizesquarefeet']]
lm2 = LinearRegression()
lm.fit(x, y_train)
predictions['lm3'] = lm.predict(z)
predictions.head()
# Out:
#           actual      simple_lm      lm_top2x      lm_top3x      lm_top4x  \
# 21619   324551.0  242309.058958  2.084590e+05  1.782790e+05  1.443990e+05
# 9827    271013.0  237971.349836  2.281397e+05  2.706052e+05  3.281130e+05
# 17521   117015.0  347859.980931  3.399862e+05  3.500576e+05  3.524372e+05
# 26823   247786.0  356053.431495  5.078790e+05  4.703246e+05  4.416271e+05
# 21839  2690733.0  996347.494698  1.011887e+06  1.036285e+06  1.137089e+06
#
#             lm_allx  polynomial degree 2  polynomial_interaction_only  \
# 21619  1.473943e+05         2.322444e+05                 2.416460e+05
# 9827   3.689665e+05         4.275721e+05                 3.657399e+05
# 17521  3.597829e+05         3.390904e+05                 3.537123e+05
# 26823  4.601591e+05         3.498361e+05                 3.549836e+05
# 21839  1.199510e+06         1.996239e+06                 1.892350e+06
#
#             baseline           lm1           lm2           lm3
# 21619  377071.081102  2.103221e+05  2.360834e+05  2.438059e+05
# 9827   377071.081102  2.859655e+05  2.487405e+05  2.912570e+05
# 17521  377071.081102  3.462766e+05  3.506079e+05  3.573155e+05
# 26823  377071.081102  3.568302e+05  3.415250e+05  3.806159e+05
# 21839  377071.081102  1.100328e+06  1.001794e+06  1.076989e+06

# %%
x = x_train_scaled_df[['calculatedfinishedsquarefeet', 'yearbuilt', 'bathroomcnt']]
z = x_validate_scaled_df[['calculatedfinishedsquarefeet', 'yearbuilt', 'bathroomcnt']]
lm2 = LinearRegression()
lm.fit(x, y_train)
predictions['lm_top3x'] = lm.predict(z)
predictions.head()
# Out:
#           actual      simple_lm      lm_top2x      lm_top3x
# 21619   324551.0  242309.058958  2.084590e+05  1.782790e+05
# 9827    271013.0  237971.349836  2.281397e+05  2.706052e+05
# 17521   117015.0  347859.980931  3.399862e+05  3.500576e+05
# 26823   247786.0  356053.431495  5.078790e+05  4.703246e+05
# 21839  2690733.0  996347.494698  1.011887e+06  1.036285e+06

# %%
x = x_train_scaled_df[['calculatedfinishedsquarefeet', 'yearbuilt', 'bedroomcnt']]
z = x_validate_scaled_df[['calculatedfinishedsquarefeet', 'yearbuilt', 'bedroomcnt']]
lm2 = LinearRegression()
lm.fit(x, y_train)
predictions['lm4'] = lm.predict(z)
predictions.head()
# Out:
#           actual      simple_lm      lm_top2x      lm_top3x      lm_top4x  \
# 21619   324551.0  242309.058958  2.084590e+05  1.782790e+05  1.443990e+05
# 9827    271013.0  237971.349836  2.281397e+05  2.706052e+05  3.281130e+05
# 17521   117015.0  347859.980931  3.399862e+05  3.500576e+05  3.524372e+05
# 26823   247786.0  356053.431495  5.078790e+05  4.703246e+05  4.416271e+05
# 21839  2690733.0  996347.494698  1.011887e+06  1.036285e+06  1.137089e+06
#
#             lm_allx  polynomial degree 2  polynomial_interaction_only  \
# 21619  1.473943e+05         2.322444e+05                 2.416460e+05
# 9827   3.689665e+05         4.275721e+05                 3.657399e+05
# 17521  3.597829e+05         3.390904e+05                 3.537123e+05
# 26823  4.601591e+05         3.498361e+05                 3.549836e+05
# 21839  1.199510e+06         1.996239e+06                 1.892350e+06
#
#             baseline           lm1           lm2           lm3           lm4
# 21619  377071.081102  2.103221e+05  2.360834e+05  2.438059e+05  1.875493e+05
# 9827   377071.081102  2.859655e+05  2.487405e+05  2.912570e+05  2.656943e+05
# 17521  377071.081102  3.462766e+05  3.506079e+05  3.573155e+05  3.395831e+05
# 26823  377071.081102  3.568302e+05  3.415250e+05  3.806159e+05  4.929902e+05
# 21839  377071.081102  1.100328e+06  1.001794e+06  1.076989e+06  1.089493e+06

# %%
x = x_train_scaled_df[['calculatedfinishedsquarefeet', 'yearbuilt', 'lotsizesquarefeet']]
z = x_validate_scaled_df[['calculatedfinishedsquarefeet', 'yearbuilt', 'lotsizesquarefeet']]
lm2 = LinearRegression()
lm.fit(x, y_train)
predictions['lm5'] = lm.predict(z)
predictions.head()
# Out:
#           actual      simple_lm      lm_top2x      lm_top3x      lm_top4x  \
# 21619   324551.0  242309.058958  2.084590e+05  1.782790e+05  1.443990e+05
# 9827    271013.0  237971.349836  2.281397e+05  2.706052e+05  3.281130e+05
# 17521   117015.0  347859.980931  3.399862e+05  3.500576e+05  3.524372e+05
# 26823   247786.0  356053.431495  5.078790e+05  4.703246e+05  4.416271e+05
# 21839  2690733.0  996347.494698  1.011887e+06  1.036285e+06  1.137089e+06
#
#             lm_allx  polynomial degree 2  polynomial_interaction_only  \
# 21619  1.473943e+05         2.322444e+05                 2.416460e+05
# 9827   3.689665e+05         4.275721e+05                 3.657399e+05
# 17521  3.597829e+05         3.390904e+05                 3.537123e+05
# 26823  4.601591e+05         3.498361e+05                 3.549836e+05
# 21839  1.199510e+06         1.996239e+06                 1.892350e+06
#
#             baseline           lm1           lm2           lm3           lm4  \
# 21619  377071.081102  2.103221e+05  2.360834e+05  2.438059e+05  1.875493e+05
# 9827   377071.081102  2.859655e+05  2.487405e+05  2.912570e+05  2.656943e+05
# 17521  377071.081102  3.462766e+05  3.506079e+05  3.573155e+05  3.395831e+05
# 26823  377071.081102  3.568302e+05  3.415250e+05  3.806159e+05  4.929902e+05
# 21839  377071.081102  1.100328e+06  1.001794e+06  1.076989e+06  1.089493e+06
#
#                 lm5
# 21619  2.103746e+05
# 9827   2.748397e+05
# 17521  3.483833e+05
# 26823  5.265939e+05
# 21839  1.082015e+06

# %%
x = x_train_scaled_df[['calculatedfinishedsquarefeet', 'yearbuilt', 'bathroomcnt', 'bedroomcnt']]
z = x_validate_scaled_df[['calculatedfinishedsquarefeet', 'yearbuilt', 'bathroomcnt', 'bedroomcnt']]
lm2 = LinearRegression()
lm.fit(x, y_train)
predictions['lm_top4x'] = lm.predict(z)
predictions.head()
# Out:
#           actual      simple_lm      lm_top2x      lm_top3x      lm_top4x
# 21619   324551.0  242309.058958  2.084590e+05  1.782790e+05  1.443990e+05
# 9827    271013.0  237971.349836  2.281397e+05  2.706052e+05  3.281130e+05
# 17521   117015.0  347859.980931  3.399862e+05  3.500576e+05  3.524372e+05
# 26823   247786.0  356053.431495  5.078790e+05  4.703246e+05  4.416271e+05
# 21839  2690733.0  996347.494698  1.011887e+06  1.036285e+06  1.137089e+06

# %%
x = x_train_scaled_df[['calculatedfinishedsquarefeet', 'bathroomcnt', 'bedroomcnt']]
z = x_validate_scaled_df[['calculatedfinishedsquarefeet', 'bathroomcnt', 'bedroomcnt']]
lm2 = LinearRegression()
lm.fit(x, y_train)
predictions['lm6'] = lm.predict(z)
predictions.head()
# Out:
#           actual      simple_lm      lm_top2x      lm_top3x      lm_top4x  \
# 21619   324551.0  242309.058958  2.084590e+05  1.782790e+05  1.443990e+05
# 9827    271013.0  237971.349836  2.281397e+05  2.706052e+05  3.281130e+05
# 17521   117015.0  347859.980931  3.399862e+05  3.500576e+05  3.524372e+05
# 26823   247786.0  356053.431495  5.078790e+05  4.703246e+05  4.416271e+05
# 21839  2690733.0  996347.494698  1.011887e+06  1.036285e+06  1.137089e+06
#
#             lm_allx  polynomial degree 2  polynomial_interaction_only  \
# 21619  1.473943e+05         2.322444e+05                 2.416460e+05
# 9827   3.689665e+05         4.275721e+05                 3.657399e+05
# 17521  3.597829e+05         3.390904e+05                 3.537123e+05
# 26823  4.601591e+05         3.498361e+05                 3.549836e+05
# 21839  1.199510e+06         1.996239e+06                 1.892350e+06
#
#             baseline           lm1           lm2           lm3           lm4  \
# 21619  377071.081102  2.103221e+05  2.360834e+05  2.438059e+05  1.875493e+05
# 9827   377071.081102  2.859655e+05  2.487405e+05  2.912570e+05  2.656943e+05
# 17521  377071.081102  3.462766e+05  3.506079e+05  3.573155e+05  3.395831e+05
# 26823  377071.081102  3.568302e+05  3.415250e+05  3.806159e+05  4.929902e+05
# 21839  377071.081102  1.100328e+06  1.001794e+06  1.076989e+06  1.089493e+06
#
#                 lm5           lm6
# 21619  2.103746e+05  1.905102e+05
# 9827   2.748397e+05  3.194827e+05
# 17521  3.483833e+05  3.534089e+05
# 26823  5.265939e+05  3.183409e+05
# 21839  1.082015e+06  1.125464e+06

# %%
x = x_train_scaled_df[['calculatedfinishedsquarefeet', 'yearbuilt', 'bathroomcnt', 'bedroomcnt', 'lotsizesquarefeet']]
z = x_validate_scaled_df[['calculatedfinishedsquarefeet', 'yearbuilt', 'bathroomcnt', 'bedroomcnt', 'lotsizesquarefeet']]
lm2 = LinearRegression()
lm.fit(x, y_train)
predictions['lm_allx'] = lm.predict(z)
predictions.head()
# Out:
#           actual      simple_lm      lm_top2x      lm_top3x      lm_top4x  \
# 21619   324551.0  242309.058958  2.084590e+05  1.782790e+05  1.443990e+05
# 9827    271013.0  237971.349836  2.281397e+05  2.706052e+05  3.281130e+05
# 17521   117015.0  347859.980931  3.399862e+05  3.500576e+05  3.524372e+05
# 26823   247786.0  356053.431495  5.078790e+05  4.703246e+05  4.416271e+05
# 21839  2690733.0  996347.494698  1.011887e+06  1.036285e+06  1.137089e+06
#
#             lm_allx
# 21619  1.473943e+05
# 9827   3.689665e+05
# 17521  3.597829e+05
# 26823  4.601591e+05
# 21839  1.199510e+06

# %%
poly = PolynomialFeatures(degree=2, include_bias=False, interaction_only=False)
poly.fit(x_train_scaled_df)
x_train_poly = pd.DataFrame(
    poly.transform(x_train_scaled_df),
    columns=poly.get_feature_names(x_train_scaled_df.columns),
    index=x_train_scaled_df.index,
)
x_train_poly.head()
# Out:
#        bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  yearbuilt  \
# 17792    0.666667     0.333333                      0.544183   0.552239
# 45565    0.333333     0.000000                      0.322950   0.537313
# 51094    0.000000     0.000000                      0.231405   0.313433
# 44347    0.666667     0.333333                      0.439924   0.231343
# 32759    0.333333     0.333333                      0.434838   0.537313
#
#        lotsizesquarefeet  bedroomcnt^2  bedroomcnt bathroomcnt  \
# 17792           0.795967      0.444444                0.222222
# 45565           0.519208      0.111111                0.000000
# 51094           0.141345      0.000000                0.000000
# 44347           0.303860      0.444444                0.222222
# 32759           0.482982      0.111111                0.111111
#
#        bedroomcnt calculatedfinishedsquarefeet  bedroomcnt yearbuilt  \
# 17792                                 0.362789              0.368159
# 45565                                 0.107650              0.179104
# 51094                                 0.000000              0.000000
# 44347                                 0.293282              0.154229
# 32759                                 0.144946              0.179104
#
#        bedroomcnt lotsizesquarefeet  bathroomcnt^2  \
# 17792                      0.530645       0.111111
# 45565                      0.173069       0.000000
# 51094                      0.000000       0.000000
# 44347                      0.202573       0.111111
# 32759                      0.160994       0.111111
#
#        bathroomcnt calculatedfinishedsquarefeet  bathroomcnt yearbuilt  \
# 17792                                  0.181394               0.184080
# 45565                                  0.000000               0.000000
# 51094                                  0.000000               0.000000
# 44347                                  0.146641               0.077114
# 32759                                  0.144946               0.179104
#
#        bathroomcnt lotsizesquarefeet  calculatedfinishedsquarefeet^2  \
# 17792                       0.265322                        0.296135
# 45565                       0.000000                        0.104297
# 51094                       0.000000                        0.053548
# 44347                       0.101287                        0.193533
# 32759                       0.160994                        0.189084
#
#        calculatedfinishedsquarefeet yearbuilt  \
# 17792                                0.300519
# 45565                                0.173525
# 51094                                0.072530
# 44347                                0.101773
# 32759                                0.233644
#
#        calculatedfinishedsquarefeet lotsizesquarefeet  yearbuilt^2  \
# 17792                                        0.433152     0.304968
# 45565                                        0.167678     0.288706
# 51094                                        0.032708     0.098240
# 44347                                        0.133675     0.053520
# 32759                                        0.210019     0.288706
#
#        yearbuilt lotsizesquarefeet  lotsizesquarefeet^2
# 17792                     0.439564             0.633563
# 45565                     0.278977             0.269577
# 51094                     0.044302             0.019978
# 44347                     0.070296             0.092331
# 32759                     0.259513             0.233272

# %%
poly_rm = LinearRegression()
poly_rm.fit(x_train_poly, y_train)

x_validate_poly = poly.transform(x_validate_scaled_df)
predictions['polynomial degree 2'] = poly_rm.predict(x_validate_poly)
predictions.head()
# Out:
#           actual      simple_lm      lm_top2x      lm_top3x      lm_top4x  \
# 21619   324551.0  242309.058958  2.084590e+05  1.782790e+05  1.443990e+05
# 9827    271013.0  237971.349836  2.281397e+05  2.706052e+05  3.281130e+05
# 17521   117015.0  347859.980931  3.399862e+05  3.500576e+05  3.524372e+05
# 26823   247786.0  356053.431495  5.078790e+05  4.703246e+05  4.416271e+05
# 21839  2690733.0  996347.494698  1.011887e+06  1.036285e+06  1.137089e+06
#
#             lm_allx  polynomial degree 2
# 21619  1.473943e+05         2.322444e+05
# 9827   3.689665e+05         4.275721e+05
# 17521  3.597829e+05         3.390904e+05
# 26823  4.601591e+05         3.498361e+05
# 21839  1.199510e+06         1.996239e+06

# %%
poly = PolynomialFeatures(degree=2, include_bias=False, interaction_only=True)
poly.fit(x_train_scaled_df)
x_train_poly = pd.DataFrame(
    poly.transform(x_train_scaled_df),
    columns=poly.get_feature_names(x_train_scaled_df.columns),
    index=x_train_scaled_df.index,
)
x_train_poly.head()
# Out:
#        bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  yearbuilt  \
# 17792    0.666667     0.333333                      0.544183   0.552239
# 45565    0.333333     0.000000                      0.322950   0.537313
# 51094    0.000000     0.000000                      0.231405   0.313433
# 44347    0.666667     0.333333                      0.439924   0.231343
# 32759    0.333333     0.333333                      0.434838   0.537313
#
#        lotsizesquarefeet  bedroomcnt bathroomcnt  \
# 17792           0.795967                0.222222
# 45565           0.519208                0.000000
# 51094           0.141345                0.000000
# 44347           0.303860                0.222222
# 32759           0.482982                0.111111
#
#        bedroomcnt calculatedfinishedsquarefeet  bedroomcnt yearbuilt  \
# 17792                                 0.362789              0.368159
# 45565                                 0.107650              0.179104
# 51094                                 0.000000              0.000000
# 44347                                 0.293282              0.154229
# 32759                                 0.144946              0.179104
#
#        bedroomcnt lotsizesquarefeet  bathroomcnt calculatedfinishedsquarefeet  \
# 17792                      0.530645                                  0.181394
# 45565                      0.173069                                  0.000000
# 51094                      0.000000                                  0.000000
# 44347                      0.202573                                  0.146641
# 32759                      0.160994                                  0.144946
#
#        bathroomcnt yearbuilt  bathroomcnt lotsizesquarefeet  \
# 17792               0.184080                       0.265322
# 45565               0.000000                       0.000000
# 51094               0.000000                       0.000000
# 44347               0.077114                       0.101287
# 32759               0.179104                       0.160994
#
#        calculatedfinishedsquarefeet yearbuilt  \
# 17792                                0.300519
# 45565                                0.173525
# 51094                                0.072530
# 44347                                0.101773
# 32759                                0.233644
#
#        calculatedfinishedsquarefeet lotsizesquarefeet  \
# 17792                                        0.433152
# 45565                                        0.167678
# 51094                                        0.032708
# 44347                                        0.133675
# 32759                                        0.210019
#
#        yearbuilt lotsizesquarefeet
# 17792                     0.439564
# 45565                     0.278977
# 51094                     0.044302
# 44347                     0.070296
# 32759                     0.259513

# %%
poly_rm = LinearRegression()
poly_rm.fit(x_train_poly, y_train)

x_validate_poly = poly.transform(x_validate_scaled_df)
predictions['polynomial_interaction_only'] = poly_rm.predict(x_validate_poly)
predictions.head()
# Out:
#           actual      simple_lm      lm_top2x      lm_top3x      lm_top4x  \
# 21619   324551.0  242309.058958  2.084590e+05  1.782790e+05  1.443990e+05
# 9827    271013.0  237971.349836  2.281397e+05  2.706052e+05  3.281130e+05
# 17521   117015.0  347859.980931  3.399862e+05  3.500576e+05  3.524372e+05
# 26823   247786.0  356053.431495  5.078790e+05  4.703246e+05  4.416271e+05
# 21839  2690733.0  996347.494698  1.011887e+06  1.036285e+06  1.137089e+06
#
#             lm_allx  polynomial degree 2  polynomial_interaction_only
# 21619  1.473943e+05         2.322444e+05                 2.416460e+05
# 9827   3.689665e+05         4.275721e+05                 3.657399e+05
# 17521  3.597829e+05         3.390904e+05                 3.537123e+05
# 26823  4.601591e+05         3.498361e+05                 3.549836e+05
# 21839  1.199510e+06         1.996239e+06                 1.892350e+06

# %%
x_train_poly_cols = x_train_scaled_df[['calculatedfinishedsquarefeet', 'yearbuilt', 'bathroomcnt']]
x_val_poly_cols = x_validate_scaled_df[['calculatedfinishedsquarefeet', 'yearbuilt', 'bathroomcnt']]
poly = PolynomialFeatures(degree=2, include_bias=False, interaction_only=False)
poly.fit(x_train_poly_cols)
x_train_poly = pd.DataFrame(
    poly.transform(x_train_poly_cols),
    columns=poly.get_feature_names(x_train_poly_cols.columns),
    index=x_train_poly_cols.index,
)

poly_rm = LinearRegression()
poly_rm.fit(x_train_poly, y_train)

x_validate_poly = poly.transform(x_val_poly_cols)
predictions['polynomial3'] = poly_rm.predict(x_validate_poly)
predictions.head()
# Out:
#           actual      simple_lm      lm_top2x      lm_top3x      lm_top4x  \
# 21619   324551.0  242309.058958  2.084590e+05  1.782790e+05  1.443990e+05
# 9827    271013.0  237971.349836  2.281397e+05  2.706052e+05  3.281130e+05
# 17521   117015.0  347859.980931  3.399862e+05  3.500576e+05  3.524372e+05
# 26823   247786.0  356053.431495  5.078790e+05  4.703246e+05  4.416271e+05
# 21839  2690733.0  996347.494698  1.011887e+06  1.036285e+06  1.137089e+06
#
#             lm_allx  polynomial degree 2  polynomial_interaction_only  \
# 21619  1.473943e+05         2.322444e+05                 2.416460e+05
# 9827   3.689665e+05         4.275721e+05                 3.657399e+05
# 17521  3.597829e+05         3.390904e+05                 3.537123e+05
# 26823  4.601591e+05         3.498361e+05                 3.549836e+05
# 21839  1.199510e+06         1.996239e+06                 1.892350e+06
#
#             baseline           lm1           lm2           lm3           lm4  \
# 21619  377071.081102  2.103221e+05  2.360834e+05  2.438059e+05  1.875493e+05
# 9827   377071.081102  2.859655e+05  2.487405e+05  2.912570e+05  2.656943e+05
# 17521  377071.081102  3.462766e+05  3.506079e+05  3.573155e+05  3.395831e+05
# 26823  377071.081102  3.568302e+05  3.415250e+05  3.806159e+05  4.929902e+05
# 21839  377071.081102  1.100328e+06  1.001794e+06  1.076989e+06  1.089493e+06
#
#                 lm5           lm6   polynomial3
# 21619  2.103746e+05  1.905102e+05  2.440549e+05
# 9827   2.748397e+05  3.194827e+05  2.633857e+05
# 17521  3.483833e+05  3.534089e+05  3.333211e+05
# 26823  5.265939e+05  3.183409e+05  3.958782e+05
# 21839  1.082015e+06  1.125464e+06  1.501944e+06

# %%
x_train_poly_cols = x_train_scaled_df[['calculatedfinishedsquarefeet', 'yearbuilt', 'bathroomcnt']]
x_val_poly_cols = x_validate_scaled_df[['calculatedfinishedsquarefeet', 'yearbuilt', 'bathroomcnt']]
poly = PolynomialFeatures(degree=2, include_bias=False, interaction_only=True)
poly.fit(x_train_poly_cols)
x_train_poly = pd.DataFrame(
    poly.transform(x_train_poly_cols),
    columns=poly.get_feature_names(x_train_poly_cols.columns),
    index=x_train_poly_cols.index,
)

poly_rm = LinearRegression()
poly_rm.fit(x_train_poly, y_train)

x_validate_poly = poly.transform(x_val_poly_cols)
predictions['polynomial3_intsonly'] = poly_rm.predict(x_validate_poly)
predictions.head()
# Out:
#           actual      simple_lm      lm_top2x      lm_top3x      lm_top4x  \
# 21619   324551.0  242309.058958  2.084590e+05  1.782790e+05  1.443990e+05
# 9827    271013.0  237971.349836  2.281397e+05  2.706052e+05  3.281130e+05
# 17521   117015.0  347859.980931  3.399862e+05  3.500576e+05  3.524372e+05
# 26823   247786.0  356053.431495  5.078790e+05  4.703246e+05  4.416271e+05
# 21839  2690733.0  996347.494698  1.011887e+06  1.036285e+06  1.137089e+06
#
#             lm_allx  polynomial degree 2  polynomial_interaction_only  \
# 21619  1.473943e+05         2.322444e+05                 2.416460e+05
# 9827   3.689665e+05         4.275721e+05                 3.657399e+05
# 17521  3.597829e+05         3.390904e+05                 3.537123e+05
# 26823  4.601591e+05         3.498361e+05                 3.549836e+05
# 21839  1.199510e+06         1.996239e+06                 1.892350e+06
#
#             baseline           lm1           lm2           lm3           lm4  \
# 21619  377071.081102  2.103221e+05  2.360834e+05  2.438059e+05  1.875493e+05
# 9827   377071.081102  2.859655e+05  2.487405e+05  2.912570e+05  2.656943e+05
# 17521  377071.081102  3.462766e+05  3.506079e+05  3.573155e+05  3.395831e+05
# 26823  377071.081102  3.568302e+05  3.415250e+05  3.806159e+05  4.929902e+05
# 21839  377071.081102  1.100328e+06  1.001794e+06  1.076989e+06  1.089493e+06
#
#                 lm5           lm6   polynomial3   polynomial4  \
# 21619  2.103746e+05  1.905102e+05  2.440549e+05  2.393778e+05
# 9827   2.748397e+05  3.194827e+05  2.633857e+05  3.105718e+05
# 17521  3.483833e+05  3.534089e+05  3.333211e+05  3.354311e+05
# 26823  5.265939e+05  3.183409e+05  3.958782e+05  3.692664e+05
# 21839  1.082015e+06  1.125464e+06  1.501944e+06  1.727687e+06
#
#        polynomial3_intsonly
# 21619          2.444710e+05
# 9827           2.518943e+05
# 17521          3.359203e+05
# 26823          3.970599e+05
# 21839          1.480431e+06

# %%
x_train_poly_cols = x_train_scaled_df[['calculatedfinishedsquarefeet', 'yearbuilt', 'bathroomcnt', 'bedroomcnt']]
x_val_poly_cols = x_validate_scaled_df[['calculatedfinishedsquarefeet', 'yearbuilt', 'bathroomcnt', 'bedroomcnt']]
poly = PolynomialFeatures(degree=2, include_bias=False, interaction_only=False)
poly.fit(x_train_poly_cols)
x_train_poly = pd.DataFrame(
    poly.transform(x_train_poly_cols),
    columns=poly.get_feature_names(x_train_poly_cols.columns),
    index=x_train_poly_cols.index,
)

poly_rm = LinearRegression()
poly_rm.fit(x_train_poly, y_train)

x_validate_poly = poly.transform(x_val_poly_cols)
predictions['polynomial4'] = poly_rm.predict(x_validate_poly)
predictions.head()
# Out:
#           actual      simple_lm      lm_top2x      lm_top3x      lm_top4x  \
# 21619   324551.0  242309.058958  2.084590e+05  1.782790e+05  1.443990e+05
# 9827    271013.0  237971.349836  2.281397e+05  2.706052e+05  3.281130e+05
# 17521   117015.0  347859.980931  3.399862e+05  3.500576e+05  3.524372e+05
# 26823   247786.0  356053.431495  5.078790e+05  4.703246e+05  4.416271e+05
# 21839  2690733.0  996347.494698  1.011887e+06  1.036285e+06  1.137089e+06
#
#             lm_allx  polynomial degree 2  polynomial_interaction_only  \
# 21619  1.473943e+05         2.322444e+05                 2.416460e+05
# 9827   3.689665e+05         4.275721e+05                 3.657399e+05
# 17521  3.597829e+05         3.390904e+05                 3.537123e+05
# 26823  4.601591e+05         3.498361e+05                 3.549836e+05
# 21839  1.199510e+06         1.996239e+06                 1.892350e+06
#
#             baseline           lm1           lm2           lm3           lm4  \
# 21619  377071.081102  2.103221e+05  2.360834e+05  2.438059e+05  1.875493e+05
# 9827   377071.081102  2.859655e+05  2.487405e+05  2.912570e+05  2.656943e+05
# 17521  377071.081102  3.462766e+05  3.506079e+05  3.573155e+05  3.395831e+05
# 26823  377071.081102  3.568302e+05  3.415250e+05  3.806159e+05  4.929902e+05
# 21839  377071.081102  1.100328e+06  1.001794e+06  1.076989e+06  1.089493e+06
#
#                 lm5           lm6   polynomial3   polynomial4
# 21619  2.103746e+05  1.905102e+05  2.440549e+05  2.393778e+05
# 9827   2.748397e+05  3.194827e+05  2.633857e+05  3.105718e+05
# 17521  3.483833e+05  3.534089e+05  3.333211e+05  3.354311e+05
# 26823  5.265939e+05  3.183409e+05  3.958782e+05  3.692664e+05
# 21839  1.082015e+06  1.125464e+06  1.501944e+06  1.727687e+06

# %%
x_train_poly_cols = x_train_scaled_df[['calculatedfinishedsquarefeet', 'yearbuilt', 'bathroomcnt', 'bedroomcnt']]
x_val_poly_cols = x_validate_scaled_df[['calculatedfinishedsquarefeet', 'yearbuilt', 'bathroomcnt', 'bedroomcnt']]
poly = PolynomialFeatures(degree=2, include_bias=False, interaction_only=True)
poly.fit(x_train_poly_cols)
x_train_poly = pd.DataFrame(
    poly.transform(x_train_poly_cols),
    columns=poly.get_feature_names(x_train_poly_cols.columns),
    index=x_train_poly_cols.index,
)

poly_rm = LinearRegression()
poly_rm.fit(x_train_poly, y_train)

x_validate_poly = poly.transform(x_val_poly_cols)
predictions['polynomial4_intsonly'] = poly_rm.predict(x_validate_poly)
predictions.head()
# Out:
#           actual      simple_lm      lm_top2x      lm_top3x      lm_top4x  \
# 21619   324551.0  242309.058958  2.084590e+05  1.782790e+05  1.443990e+05
# 9827    271013.0  237971.349836  2.281397e+05  2.706052e+05  3.281130e+05
# 17521   117015.0  347859.980931  3.399862e+05  3.500576e+05  3.524372e+05
# 26823   247786.0  356053.431495  5.078790e+05  4.703246e+05  4.416271e+05
# 21839  2690733.0  996347.494698  1.011887e+06  1.036285e+06  1.137089e+06
#
#             lm_allx  polynomial degree 2  polynomial_interaction_only  \
# 21619  1.473943e+05         2.322444e+05                 2.416460e+05
# 9827   3.689665e+05         4.275721e+05                 3.657399e+05
# 17521  3.597829e+05         3.390904e+05                 3.537123e+05
# 26823  4.601591e+05         3.498361e+05                 3.549836e+05
# 21839  1.199510e+06         1.996239e+06                 1.892350e+06
#
#             baseline           lm1           lm2           lm3           lm4  \
# 21619  377071.081102  2.103221e+05  2.360834e+05  2.438059e+05  1.875493e+05
# 9827   377071.081102  2.859655e+05  2.487405e+05  2.912570e+05  2.656943e+05
# 17521  377071.081102  3.462766e+05  3.506079e+05  3.573155e+05  3.395831e+05
# 26823  377071.081102  3.568302e+05  3.415250e+05  3.806159e+05  4.929902e+05
# 21839  377071.081102  1.100328e+06  1.001794e+06  1.076989e+06  1.089493e+06
#
#                 lm5           lm6   polynomial3   polynomial4  \
# 21619  2.103746e+05  1.905102e+05  2.440549e+05  2.393778e+05
# 9827   2.748397e+05  3.194827e+05  2.633857e+05  3.105718e+05
# 17521  3.483833e+05  3.534089e+05  3.333211e+05  3.354311e+05
# 26823  5.265939e+05  3.183409e+05  3.958782e+05  3.692664e+05
# 21839  1.082015e+06  1.125464e+06  1.501944e+06  1.727687e+06
#
#        polynomial3_intsonly  polynomial4_intsonly
# 21619          2.444710e+05          2.387068e+05
# 9827           2.518943e+05          2.946359e+05
# 17521          3.359203e+05          3.435486e+05
# 26823          3.970599e+05          3.788246e+05
# 21839          1.480431e+06          1.677504e+06

# %%
x_train_poly_cols = x_train_scaled_df[['calculatedfinishedsquarefeet', 'yearbuilt']]
x_val_poly_cols = x_validate_scaled_df[['calculatedfinishedsquarefeet', 'yearbuilt']]
poly = PolynomialFeatures(degree=2, include_bias=False, interaction_only=False)
poly.fit(x_train_poly_cols)
x_train_poly = pd.DataFrame(
    poly.transform(x_train_poly_cols),
    columns=poly.get_feature_names(x_train_poly_cols.columns),
    index=x_train_poly_cols.index,
)

poly_rm = LinearRegression()
poly_rm.fit(x_train_poly, y_train)

x_validate_poly = poly.transform(x_val_poly_cols)
predictions['polynomial5'] = poly_rm.predict(x_validate_poly)
predictions.head()
# Out:
#           actual      simple_lm      lm_top2x      lm_top3x      lm_top4x  \
# 21619   324551.0  242309.058958  2.084590e+05  1.782790e+05  1.443990e+05
# 9827    271013.0  237971.349836  2.281397e+05  2.706052e+05  3.281130e+05
# 17521   117015.0  347859.980931  3.399862e+05  3.500576e+05  3.524372e+05
# 26823   247786.0  356053.431495  5.078790e+05  4.703246e+05  4.416271e+05
# 21839  2690733.0  996347.494698  1.011887e+06  1.036285e+06  1.137089e+06
#
#             lm_allx  polynomial degree 2  polynomial_interaction_only  \
# 21619  1.473943e+05         2.322444e+05                 2.416460e+05
# 9827   3.689665e+05         4.275721e+05                 3.657399e+05
# 17521  3.597829e+05         3.390904e+05                 3.537123e+05
# 26823  4.601591e+05         3.498361e+05                 3.549836e+05
# 21839  1.199510e+06         1.996239e+06                 1.892350e+06
#
#             baseline           lm1           lm2           lm3           lm4  \
# 21619  377071.081102  2.103221e+05  2.360834e+05  2.438059e+05  1.875493e+05
# 9827   377071.081102  2.859655e+05  2.487405e+05  2.912570e+05  2.656943e+05
# 17521  377071.081102  3.462766e+05  3.506079e+05  3.573155e+05  3.395831e+05
# 26823  377071.081102  3.568302e+05  3.415250e+05  3.806159e+05  4.929902e+05
# 21839  377071.081102  1.100328e+06  1.001794e+06  1.076989e+06  1.089493e+06
#
#                 lm5           lm6   polynomial3   polynomial4  \
# 21619  2.103746e+05  1.905102e+05  2.440549e+05  2.393778e+05
# 9827   2.748397e+05  3.194827e+05  2.633857e+05  3.105718e+05
# 17521  3.483833e+05  3.534089e+05  3.333211e+05  3.354311e+05
# 26823  5.265939e+05  3.183409e+05  3.958782e+05  3.692664e+05
# 21839  1.082015e+06  1.125464e+06  1.501944e+06  1.727687e+06
#
#        polynomial3_intsonly  polynomial4_intsonly   polynomial5
# 21619          2.444710e+05          2.387068e+05  2.469264e+05
# 9827           2.518943e+05          2.946359e+05  2.546918e+05
# 17521          3.359203e+05          3.435486e+05  3.339444e+05
# 26823          3.970599e+05          3.788246e+05  4.437158e+05
# 21839          1.480431e+06          1.677504e+06  1.316588e+06

# %%
x_train_poly_cols = x_train_scaled_df[['calculatedfinishedsquarefeet', 'yearbuilt']]
x_val_poly_cols = x_validate_scaled_df[['calculatedfinishedsquarefeet', 'yearbuilt']]
poly = PolynomialFeatures(degree=2, include_bias=False, interaction_only=True)
poly.fit(x_train_poly_cols)
x_train_poly = pd.DataFrame(
    poly.transform(x_train_poly_cols),
    columns=poly.get_feature_names(x_train_poly_cols.columns),
    index=x_train_poly_cols.index,
)

poly_rm = LinearRegression()
poly_rm.fit(x_train_poly, y_train)

x_validate_poly = poly.transform(x_val_poly_cols)
predictions['polynomial5_intsonly'] = poly_rm.predict(x_validate_poly)
predictions.head()
# Out:
#           actual      simple_lm      lm_top2x      lm_top3x      lm_top4x  \
# 21619   324551.0  242309.058958  2.084590e+05  1.782790e+05  1.443990e+05
# 9827    271013.0  237971.349836  2.281397e+05  2.706052e+05  3.281130e+05
# 17521   117015.0  347859.980931  3.399862e+05  3.500576e+05  3.524372e+05
# 26823   247786.0  356053.431495  5.078790e+05  4.703246e+05  4.416271e+05
# 21839  2690733.0  996347.494698  1.011887e+06  1.036285e+06  1.137089e+06
#
#             lm_allx  polynomial degree 2  polynomial_interaction_only  \
# 21619  1.473943e+05         2.322444e+05                 2.416460e+05
# 9827   3.689665e+05         4.275721e+05                 3.657399e+05
# 17521  3.597829e+05         3.390904e+05                 3.537123e+05
# 26823  4.601591e+05         3.498361e+05                 3.549836e+05
# 21839  1.199510e+06         1.996239e+06                 1.892350e+06
#
#             baseline           lm1  ...           lm3           lm4  \
# 21619  377071.081102  2.103221e+05  ...  2.438059e+05  1.875493e+05
# 9827   377071.081102  2.859655e+05  ...  2.912570e+05  2.656943e+05
# 17521  377071.081102  3.462766e+05  ...  3.573155e+05  3.395831e+05
# 26823  377071.081102  3.568302e+05  ...  3.806159e+05  4.929902e+05
# 21839  377071.081102  1.100328e+06  ...  1.076989e+06  1.089493e+06
#
#                 lm5           lm6   polynomial3   polynomial4  \
# 21619  2.103746e+05  1.905102e+05  2.440549e+05  2.393778e+05
# 9827   2.748397e+05  3.194827e+05  2.633857e+05  3.105718e+05
# 17521  3.483833e+05  3.534089e+05  3.333211e+05  3.354311e+05
# 26823  5.265939e+05  3.183409e+05  3.958782e+05  3.692664e+05
# 21839  1.082015e+06  1.125464e+06  1.501944e+06  1.727687e+06
#
#        polynomial3_intsonly  polynomial4_intsonly   polynomial5  \
# 21619          2.444710e+05          2.387068e+05  2.469264e+05
# 9827           2.518943e+05          2.946359e+05  2.546918e+05
# 17521          3.359203e+05          3.435486e+05  3.339444e+05
# 26823          3.970599e+05          3.788246e+05  4.437158e+05
# 21839          1.480431e+06          1.677504e+06  1.316588e+06
#
#        polynomial5_intsonly
# 21619         213119.677583
# 9827          225031.915294
# 17521         346418.048322
# 26823         496376.564926
# 21839         902907.774727
#
# [5 rows x 21 columns]

# %%
x_train_poly_cols = x_train_scaled_df[['calculatedfinishedsquarefeet']]
x_val_poly_cols = x_validate_scaled_df[['calculatedfinishedsquarefeet']]
poly = PolynomialFeatures(degree=2, include_bias=False, interaction_only=False)
poly.fit(x_train_poly_cols)
x_train_poly = pd.DataFrame(
    poly.transform(x_train_poly_cols),
    columns=poly.get_feature_names(x_train_poly_cols.columns),
    index=x_train_poly_cols.index,
)

poly_rm = LinearRegression()
poly_rm.fit(x_train_poly, y_train)

x_validate_poly = poly.transform(x_val_poly_cols)
predictions['polynomial6'] = poly_rm.predict(x_validate_poly)
predictions.head()
# Out:
#           actual      simple_lm      lm_top2x      lm_top3x      lm_top4x  \
# 21619   324551.0  242309.058958  2.084590e+05  1.782790e+05  1.443990e+05
# 9827    271013.0  237971.349836  2.281397e+05  2.706052e+05  3.281130e+05
# 17521   117015.0  347859.980931  3.399862e+05  3.500576e+05  3.524372e+05
# 26823   247786.0  356053.431495  5.078790e+05  4.703246e+05  4.416271e+05
# 21839  2690733.0  996347.494698  1.011887e+06  1.036285e+06  1.137089e+06
#
#             lm_allx  polynomial degree 2  polynomial_interaction_only  \
# 21619  1.473943e+05         2.322444e+05                 2.416460e+05
# 9827   3.689665e+05         4.275721e+05                 3.657399e+05
# 17521  3.597829e+05         3.390904e+05                 3.537123e+05
# 26823  4.601591e+05         3.498361e+05                 3.549836e+05
# 21839  1.199510e+06         1.996239e+06                 1.892350e+06
#
#             baseline           lm1  ...           lm4           lm5  \
# 21619  377071.081102  2.103221e+05  ...  1.875493e+05  2.103746e+05
# 9827   377071.081102  2.859655e+05  ...  2.656943e+05  2.748397e+05
# 17521  377071.081102  3.462766e+05  ...  3.395831e+05  3.483833e+05
# 26823  377071.081102  3.568302e+05  ...  4.929902e+05  5.265939e+05
# 21839  377071.081102  1.100328e+06  ...  1.089493e+06  1.082015e+06
#
#                 lm6   polynomial3   polynomial4  polynomial3_intsonly  \
# 21619  1.905102e+05  2.440549e+05  2.393778e+05          2.444710e+05
# 9827   3.194827e+05  2.633857e+05  3.105718e+05          2.518943e+05
# 17521  3.534089e+05  3.333211e+05  3.354311e+05          3.359203e+05
# 26823  3.183409e+05  3.958782e+05  3.692664e+05          3.970599e+05
# 21839  1.125464e+06  1.501944e+06  1.727687e+06          1.480431e+06
#
#        polynomial4_intsonly   polynomial5  polynomial5_intsonly   polynomial6
# 21619          2.387068e+05  2.469264e+05         213119.677583  2.595697e+05
# 9827           2.946359e+05  2.546918e+05         225031.915294  2.570252e+05
# 17521          3.435486e+05  3.339444e+05         346418.048322  3.339103e+05
# 26823          3.788246e+05  4.437158e+05         496376.564926  3.406795e+05
# 21839          1.677504e+06  1.316588e+06         902907.774727  1.314525e+06
#
# [5 rows x 22 columns]

# %%
x_train_poly_cols = x_train_scaled_df[['calculatedfinishedsquarefeet']]
x_val_poly_cols = x_validate_scaled_df[['calculatedfinishedsquarefeet']]
poly = PolynomialFeatures(degree=2, include_bias=False, interaction_only=True)
poly.fit(x_train_poly_cols)
x_train_poly = pd.DataFrame(
    poly.transform(x_train_poly_cols),
    columns=poly.get_feature_names(x_train_poly_cols.columns),
    index=x_train_poly_cols.index,
)

poly_rm = LinearRegression()
poly_rm.fit(x_train_poly, y_train)

x_validate_poly = poly.transform(x_val_poly_cols)
predictions['polynomial6_intsonly'] = poly_rm.predict(x_validate_poly)
predictions.head()
# Out:
#           actual      simple_lm      lm_top2x      lm_top3x      lm_top4x  \
# 21619   324551.0  242309.058958  2.084590e+05  1.782790e+05  1.443990e+05
# 9827    271013.0  237971.349836  2.281397e+05  2.706052e+05  3.281130e+05
# 17521   117015.0  347859.980931  3.399862e+05  3.500576e+05  3.524372e+05
# 26823   247786.0  356053.431495  5.078790e+05  4.703246e+05  4.416271e+05
# 21839  2690733.0  996347.494698  1.011887e+06  1.036285e+06  1.137089e+06
#
#             lm_allx  polynomial degree 2  polynomial_interaction_only  \
# 21619  1.473943e+05         2.322444e+05                 2.416460e+05
# 9827   3.689665e+05         4.275721e+05                 3.657399e+05
# 17521  3.597829e+05         3.390904e+05                 3.537123e+05
# 26823  4.601591e+05         3.498361e+05                 3.549836e+05
# 21839  1.199510e+06         1.996239e+06                 1.892350e+06
#
#             baseline           lm1  ...           lm5           lm6  \
# 21619  377071.081102  2.103221e+05  ...  2.103746e+05  1.905102e+05
# 9827   377071.081102  2.859655e+05  ...  2.748397e+05  3.194827e+05
# 17521  377071.081102  3.462766e+05  ...  3.483833e+05  3.534089e+05
# 26823  377071.081102  3.568302e+05  ...  5.265939e+05  3.183409e+05
# 21839  377071.081102  1.100328e+06  ...  1.082015e+06  1.125464e+06
#
#         polynomial3   polynomial4  polynomial3_intsonly  polynomial4_intsonly  \
# 21619  2.440549e+05  2.393778e+05          2.444710e+05          2.387068e+05
# 9827   2.633857e+05  3.105718e+05          2.518943e+05          2.946359e+05
# 17521  3.333211e+05  3.354311e+05          3.359203e+05          3.435486e+05
# 26823  3.958782e+05  3.692664e+05          3.970599e+05          3.788246e+05
# 21839  1.501944e+06  1.727687e+06          1.480431e+06          1.677504e+06
#
#         polynomial5  polynomial5_intsonly   polynomial6  polynomial6_intsonly
# 21619  2.469264e+05         213119.677583  2.595697e+05         242309.058958
# 9827   2.546918e+05         225031.915294  2.570252e+05         237971.349836
# 17521  3.339444e+05         346418.048322  3.339103e+05         347859.980931
# 26823  4.437158e+05         496376.564926  3.406795e+05         356053.431495
# 21839  1.316588e+06         902907.774727  1.314525e+06         996347.494698
#
# [5 rows x 23 columns]

# %%
predictions['baseline'] = train.taxvaluedollarcnt.mean()
predictions.head()
# Out:
#           actual      simple_lm      lm_top2x      lm_top3x      lm_top4x  \
# 21619   324551.0  242309.058958  2.084590e+05  1.782790e+05  1.443990e+05
# 9827    271013.0  237971.349836  2.281397e+05  2.706052e+05  3.281130e+05
# 17521   117015.0  347859.980931  3.399862e+05  3.500576e+05  3.524372e+05
# 26823   247786.0  356053.431495  5.078790e+05  4.703246e+05  4.416271e+05
# 21839  2690733.0  996347.494698  1.011887e+06  1.036285e+06  1.137089e+06
#
#             lm_allx  polynomial degree 2  polynomial_interaction_only  \
# 21619  1.473943e+05         2.322444e+05                 2.416460e+05
# 9827   3.689665e+05         4.275721e+05                 3.657399e+05
# 17521  3.597829e+05         3.390904e+05                 3.537123e+05
# 26823  4.601591e+05         3.498361e+05                 3.549836e+05
# 21839  1.199510e+06         1.996239e+06                 1.892350e+06
#
#             baseline
# 21619  377071.081102
# 9827   377071.081102
# 17521  377071.081102
# 26823  377071.081102
# 21839  377071.081102

# %%
def calculate_mse(y_predicted):
    return mean_squared_error(predictions.actual, y_predicted)

predictions.apply(calculate_mse)
# Out:
# actual                         0.000000e+00
# simple_lm                      3.928276e+11
# lm_top2x                       3.740913e+11
# lm_top3x                       3.737984e+11
# lm_top4x                       3.622688e+11
# lm_allx                        1.584328e+12
# polynomial degree 2            8.962272e+18
# polynomial_interaction_only    3.982990e+12
# baseline                       5.412900e+11
# lm1                            3.777704e+11
# lm2                            3.934137e+11
# lm3                            2.303325e+12
# lm4                            3.649350e+11
# lm5                            1.836986e+12
# lm6                            3.775003e+11
# polynomial3                    3.278966e+11
# polynomial4                    3.400347e+11
# polynomial3_intsonly           3.243613e+11
# polynomial4_intsonly           3.258536e+11
# polynomial5                    3.378582e+11
# polynomial5_intsonly           3.832959e+11
# polynomial6                    3.359110e+11
# polynomial6_intsonly           3.928276e+11
# dtype: float64

# %%
import math

# %%
predictions.apply(calculate_mse).apply(math.sqrt)
# Out:
# actual                         0.000000e+00
# simple_lm                      6.267596e+05
# lm_top2x                       6.116301e+05
# lm_top3x                       6.113905e+05
# lm_top4x                       6.018877e+05
# lm_allx                        1.258701e+06
# polynomial degree 2            2.993705e+09
# polynomial_interaction_only    1.995743e+06
# baseline                       7.357241e+05
# lm1                            6.146303e+05
# lm2                            6.272270e+05
# lm3                            1.517671e+06
# lm4                            6.040985e+05
# lm5                            1.355354e+06
# lm6                            6.144106e+05
# polynomial3                    5.726226e+05
# polynomial4                    5.831249e+05
# polynomial3_intsonly           5.695273e+05
# polynomial4_intsonly           5.708359e+05
# polynomial5                    5.812557e+05
# polynomial5_intsonly           6.191090e+05
# polynomial6                    5.795783e+05
# polynomial6_intsonly           6.267596e+05
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# **DF2**

# %%
train_val, test = train_test_split(df2, train_size = 0.8, random_state=123)
train, validate = train_test_split(train_val, train_size = 0.7, random_state=123)
train.shape, validate.shape, test.shape
# Out:
# ((7858, 7), (3369, 7), (2807, 7))

# %%
def remove_outliers(df, k, col_list):
    ''' this function will remove outliers from a list of columns in a dataframe 
        and return that dataframe. A list of columns with significant outliers is 
        assigned to a variable in the below wrangle function and can be modified if needed
    '''
    #loop throught the columns in the list
    for col in col_list:
        q1, q3 = df[col].quantile([.25, .75])  # get quartiles
        iqr = q3 - q1   # calculate interquartile range
        upper_bound = q3 + k * iqr   # get upper bound
        lower_bound = q1 - k * iqr   # get lower bound
        # return dataframe without outliers
        df = df[(df[col] > lower_bound) & (df[col] < upper_bound)] 
    return df

# %%
out_columns = ['bedroomcnt', 'bathroomcnt','calculatedfinishedsquarefeet', 'lotsizesquarefeet']
train = remove_outliers(train, 1.5, out_columns)

# %%
train.shape
# Out:
# (6783, 7)

# %%
train.fips.value_counts()
# Out:
# 6059.0    6783
# Name: fips, dtype: int64

# %%
x_train = train[['bedroomcnt', 'bathroomcnt', 'calculatedfinishedsquarefeet', 'yearbuilt', 'lotsizesquarefeet']]
y_train = train[['taxvaluedollarcnt']]
x_train.head()
# Out:
#        bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  yearbuilt  \
# 34201         4.0          2.5                        2269.0     1987.0
# 12805         4.0          2.0                        1522.0     1957.0
# 36501         4.0          3.5                        2902.0     2004.0
# 40593         5.0          3.0                        2396.0     2003.0
# 8354          4.0          2.5                        2003.0     1998.0
#
#        lotsizesquarefeet
# 34201             3575.0
# 12805             6865.0
# 36501             5045.0
# 40593             4239.0
# 8354              3842.0

# %%
#create a min-max scaler object
scaler = MinMaxScaler()
#fit the scaler with the train data
scaler.fit(x_train)
#output the results of the scaler into a new df to use with feature selection
x_train_scaled = scaler.transform(x_train)
x_train_scaled_df = pd.DataFrame(x_train_scaled, columns=x_train.columns, index=x_train.index)
x_train_scaled_df.head()
# Out:
#        bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  yearbuilt  \
# 34201    0.666667     0.500000                      0.516081   0.770492
# 12805    0.666667     0.333333                      0.295662   0.524590
# 36501    0.666667     0.833333                      0.702862   0.909836
# 40593    1.000000     0.666667                      0.553556   0.901639
# 8354     0.666667     0.500000                      0.437592   0.860656
#
#        lotsizesquarefeet
# 34201           0.260292
# 12805           0.542453
# 36501           0.386364
# 40593           0.317238
# 8354            0.283190

# %%
x_validate = validate[['bedroomcnt', 'bathroomcnt', 'calculatedfinishedsquarefeet', 'yearbuilt','lotsizesquarefeet']]
y_validate = validate[['taxvaluedollarcnt']]
x_validate.head()
# Out:
#        bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  yearbuilt  \
# 26610         4.0          2.0                        2286.0     1966.0
# 43427         4.0          2.0                        1748.0     1959.0
# 13685         3.0          2.0                        1592.0     1960.0
# 27127         3.0          2.5                        1801.0     1986.0
# 44264         5.0          4.0                        3831.0     1999.0
#
#        lotsizesquarefeet
# 26610             5200.0
# 43427             6120.0
# 13685             6600.0
# 27127             4950.0
# 44264            13005.0

# %%
x_validate_scaled = scaler.transform(x_validate)
x_validate_scaled_df = pd.DataFrame(x_validate_scaled, columns=x_train.columns, index=x_validate.index)
x_validate_scaled_df.head()
# Out:
#        bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  yearbuilt  \
# 26610    0.666667     0.333333                      0.521098   0.598361
# 43427    0.666667     0.333333                      0.362349   0.540984
# 13685    0.333333     0.333333                      0.316317   0.549180
# 27127    0.333333     0.500000                      0.377988   0.762295
# 44264    1.000000     1.000000                      0.976984   0.868852
#
#        lotsizesquarefeet
# 26610           0.399657
# 43427           0.478559
# 13685           0.519726
# 27127           0.378216
# 44264           1.069039

# %%
predictions2 = pd.DataFrame({'actual': validate.taxvaluedollarcnt})
predictions2.head()
# Out:
#           actual
# 26610   101539.0
# 43427   497056.0
# 13685   715000.0
# 27127   311209.0
# 44264  1750000.0

# %%
x_train_poly_cols = x_train_scaled_df[['calculatedfinishedsquarefeet', 'yearbuilt', 'bathroomcnt']]
x_val_poly_cols = x_validate_scaled_df[['calculatedfinishedsquarefeet', 'yearbuilt', 'bathroomcnt']]
poly = PolynomialFeatures(degree=2, include_bias=False, interaction_only=True)
poly.fit(x_train_poly_cols)
x_train_poly = pd.DataFrame(
    poly.transform(x_train_poly_cols),
    columns=poly.get_feature_names(x_train_poly_cols.columns),
    index=x_train_poly_cols.index,
)

poly_rm = LinearRegression()
poly_rm.fit(x_train_poly, y_train)

x_validate_poly = poly.transform(x_val_poly_cols)
predictions2['polynomial3_intsonly'] = poly_rm.predict(x_validate_poly)
predictions2.head()
# Out:
#           actual  polynomial3_intsonly
# 26610   101539.0          4.919942e+05
# 43427   497056.0          3.898563e+05
# 13685   715000.0          3.687904e+05
# 27127   311209.0          4.942068e+05
# 44264  1750000.0          1.314056e+06

# %%
predictions2['baseline'] = train.taxvaluedollarcnt.mean()
predictions2.head()
# Out:
#           actual  polynomial3_intsonly       baseline
# 26610   101539.0          4.919942e+05  501488.803332
# 43427   497056.0          3.898563e+05  501488.803332
# 13685   715000.0          3.687904e+05  501488.803332
# 27127   311209.0          4.942068e+05  501488.803332
# 44264  1750000.0          1.314056e+06  501488.803332

# %%
def calculate_mse(y_predicted):
    return mean_squared_error(predictions2.actual, y_predicted)

predictions2.apply(calculate_mse)
# Out:
# actual                  0.000000e+00
# polynomial3_intsonly    2.008305e+11
# baseline                4.033132e+11
# dtype: float64

# %%
predictions2.apply(calculate_mse).apply(math.sqrt)
# Out:
# actual                       0.000000
# polynomial3_intsonly    448141.166948
# baseline                635069.479185
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# **DF3**

# %%
train_val, test = train_test_split(df3, train_size = 0.8, random_state=123)
train, validate = train_test_split(train_val, train_size = 0.7, random_state=123)
train.shape, validate.shape, test.shape
# Out:
# ((2440, 7), (1046, 7), (872, 7))

# %%
def remove_outliers(df, k, col_list):
    ''' this function will remove outliers from a list of columns in a dataframe 
        and return that dataframe. A list of columns with significant outliers is 
        assigned to a variable in the below wrangle function and can be modified if needed
    '''
    #loop throught the columns in the list
    for col in col_list:
        q1, q3 = df[col].quantile([.25, .75])  # get quartiles
        iqr = q3 - q1   # calculate interquartile range
        upper_bound = q3 + k * iqr   # get upper bound
        lower_bound = q1 - k * iqr   # get lower bound
        # return dataframe without outliers
        df = df[(df[col] > lower_bound) & (df[col] < upper_bound)] 
    return df

# %%
out_columns = ['bedroomcnt', 'bathroomcnt','calculatedfinishedsquarefeet', 'lotsizesquarefeet']
train = remove_outliers(train, 1.5, out_columns)

# %%
train.shape
# Out:
# (2013, 7)

# %%
train.fips.value_counts()
# Out:
# 6111.0    2013
# Name: fips, dtype: int64

# %%
x_train = train[['bedroomcnt', 'bathroomcnt', 'calculatedfinishedsquarefeet', 'yearbuilt', 'lotsizesquarefeet']]
y_train = train[['taxvaluedollarcnt']]
x_train.head()
# Out:
#        bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  yearbuilt  \
# 43436         3.0          1.5                        1376.0     1962.0
# 2018          4.0          2.0                        1701.0     1965.0
# 27370         3.0          2.0                        1160.0     1973.0
# 46312         4.0          2.0                        1956.0     1964.0
# 13484         4.0          1.5                        1145.0     1962.0
#
#        lotsizesquarefeet
# 43436            10455.0
# 2018              6700.0
# 27370             7095.0
# 46312             9100.0
# 13484            10260.0

# %%
#create a min-max scaler object
scaler = MinMaxScaler()
#fit the scaler with the train data
scaler.fit(x_train)
#output the results of the scaler into a new df to use with feature selection
x_train_scaled = scaler.transform(x_train)
x_train_scaled_df = pd.DataFrame(x_train_scaled, columns=x_train.columns, index=x_train.index)
x_train_scaled_df.head()
# Out:
#        bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  yearbuilt  \
# 43436    0.333333     0.166667                      0.274847   0.582677
# 2018     0.666667     0.333333                      0.374540   0.606299
# 27370    0.333333     0.333333                      0.208589   0.669291
# 46312    0.666667     0.333333                      0.452761   0.598425
# 13484    0.666667     0.166667                      0.203988   0.582677
#
#        lotsizesquarefeet
# 43436           0.651579
# 2018            0.381377
# 27370           0.409801
# 46312           0.554076
# 13484           0.637548

# %%
x_validate = validate[['bedroomcnt', 'bathroomcnt', 'calculatedfinishedsquarefeet', 'yearbuilt','lotsizesquarefeet']]
y_validate = validate[['taxvaluedollarcnt']]
x_validate.head()
# Out:
#        bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  yearbuilt  \
# 13404         5.0          4.5                        3622.0     2006.0
# 2305          4.0          4.5                        4007.0     2000.0
# 11329         6.0          7.0                        7770.0     2004.0
# 9365          3.0          3.0                        1894.0     1959.0
# 7841          4.0          2.0                        1961.0     1962.0
#
#        lotsizesquarefeet
# 13404            10908.0
# 2305             25922.0
# 11329            46980.0
# 9365             11314.0
# 7841              9000.0

# %%
x_validate_scaled = scaler.transform(x_validate)
x_validate_scaled_df = pd.DataFrame(x_validate_scaled, columns=x_train.columns, index=x_validate.index)
x_validate_scaled_df.head()
# Out:
#        bedroomcnt  bathroomcnt  calculatedfinishedsquarefeet  yearbuilt  \
# 13404    1.000000     1.166667                      0.963804   0.929134
# 2305     0.666667     1.166667                      1.081902   0.881890
# 11329    1.333333     2.000000                      2.236196   0.913386
# 9365     0.333333     0.666667                      0.433742   0.559055
# 7841     0.666667     0.333333                      0.454294   0.582677
#
#        lotsizesquarefeet
# 13404           0.684176
# 2305            1.764554
# 11329           3.279845
# 9365            0.713391
# 7841            0.546881

# %%
predictions3 = pd.DataFrame({'actual': validate.taxvaluedollarcnt})
predictions3.head()
# Out:
#           actual
# 13404   849000.0
# 2305   1298990.0
# 11329  1636139.0
# 9365    302961.0
# 7841    376973.0

# %%
x_train_poly_cols = x_train_scaled_df[['calculatedfinishedsquarefeet', 'yearbuilt', 'bathroomcnt']]
x_val_poly_cols = x_validate_scaled_df[['calculatedfinishedsquarefeet', 'yearbuilt', 'bathroomcnt']]
poly = PolynomialFeatures(degree=2, include_bias=False, interaction_only=True)
poly.fit(x_train_poly_cols)
x_train_poly = pd.DataFrame(
    poly.transform(x_train_poly_cols),
    columns=poly.get_feature_names(x_train_poly_cols.columns),
    index=x_train_poly_cols.index,
)

poly_rm = LinearRegression()
poly_rm.fit(x_train_poly, y_train)

x_validate_poly = poly.transform(x_val_poly_cols)
predictions3['polynomial3_intsonly'] = poly_rm.predict(x_validate_poly)
predictions3.head()
# Out:
#           actual  polynomial3_intsonly
# 13404   849000.0          1.021642e+06
# 2305   1298990.0          1.112475e+06
# 11329  1636139.0          2.868169e+06
# 9365    302961.0          3.882159e+05
# 7841    376973.0          3.758642e+05

# %%
predictions3['baseline'] = train.taxvaluedollarcnt.mean()
predictions3.head()
# Out:
#           actual  polynomial3_intsonly       baseline
# 13404   849000.0          1.021642e+06  422171.300546
# 2305   1298990.0          1.112475e+06  422171.300546
# 11329  1636139.0          2.868169e+06  422171.300546
# 9365    302961.0          3.882159e+05  422171.300546
# 7841    376973.0          3.758642e+05  422171.300546

# %%
def calculate_mse(y_predicted):
    return mean_squared_error(predictions3.actual, y_predicted)

predictions3.apply(calculate_mse)
# Out:
# actual                  0.000000e+00
# polynomial3_intsonly    1.956480e+11
# baseline                3.904149e+11
# dtype: float64

# %%
predictions3.apply(calculate_mse).apply(math.sqrt)
# Out:
# actual                       0.000000
# polynomial3_intsonly    442321.150865
# baseline                624831.936752
# dtype: float64
